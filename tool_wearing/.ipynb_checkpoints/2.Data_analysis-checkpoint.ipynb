# %%
import os
import numpy as np
import pandas as pd
import pickle as pkl
import matplotlib.pyplot as plt
import seaborn as sns

path = '/home/mina-joojoo/Desktop/tool_wearing/'
dataset = pd.read_csv(path + 'all_data.csv')

# %%
dataset.describe()
# Out:
#                 VB            C         tool      machine  torq_tot_mean  \
# count  6418.000000  6418.000000  6418.000000  6418.000000    1856.000000
# mean     81.339981  2124.464475     4.968059     1.987847     221.661477
# std      30.149191  1304.602639     2.396248     0.752436       3.328708
# min       3.000000    11.000000     1.000000     1.000000     212.786804
# 25%      58.000000  1045.250000     3.000000     1.000000     219.343689
# 50%      79.000000  2048.000000     5.000000     2.000000     221.893982
# 75%     100.000000  3053.000000     7.000000     3.000000     223.989231
# max     160.000000  5181.000000     9.000000     3.000000     233.109909
#
#        torq_tot_std  torq_tot_max  torq_tot_min  torq_tot_rms  torq_tot_skew  \
# count        1856.0   1856.000000   1856.000000   1856.000000         1856.0
# mean            0.0    221.661477    221.661477    221.661477            0.0
# std             0.0      3.328708      3.328708      3.328708            0.0
# min             0.0    212.786804    212.786804    212.786804            0.0
# 25%             0.0    219.343689    219.343689    219.343689            0.0
# 50%             0.0    221.893982    221.893982    221.893982            0.0
# 75%             0.0    223.989231    223.989231    223.989231            0.0
# max             0.0    233.109909    233.109909    233.109909            0.0
#
#        ...       fy_max       fy_min       fy_rms       fy_skew      fz_mean  \
# count  ...  4562.000000  4562.000000  4562.000000  4.562000e+03  4562.000000
# mean   ...   253.683889  -776.977839   407.834715 -2.235255e+05   -64.875930
# std    ...   131.206304   656.414993   261.417056  9.973889e+06   346.016510
# min    ...   -82.031250 -2341.796875    64.097275 -8.262330e+07  -581.101440
# 25%    ...   173.000000 -1239.013672   120.062674 -1.134785e+04  -470.480530
# 50%    ...   228.349998  -917.968750   461.578003  5.014717e+03   165.440636
# 75%    ...   312.500000   -43.500000   603.914062  2.903753e+06   220.269325
# max    ...   836.914062    14.600000  1005.733154  1.505806e+07   331.674774
#
#             fz_std       fz_max       fz_min       fz_rms       fz_skew
# count  4562.000000  4562.000000  4562.000000  4562.000000  4.562000e+03
# mean    347.320740   990.113700 -1117.891620   556.186859 -3.270757e+06
# std     272.127107  1184.108680   565.818804    96.108770  1.474872e+07
# min      17.316572  -533.299988 -3574.953369   367.070618 -9.606671e+07
# 25%      23.467924  -403.050003 -1544.435028   478.975281 -5.696668e+06
# 50%     461.539551  1485.454407 -1055.052307   542.611481 -6.857768e+03
# 75%     574.160126  1957.820129  -581.500000   616.635925 -1.882440e+03
# max     940.730530  3785.176758  -485.100006   970.559509  1.343548e+08
#
# [8 rows x 88 columns]

# %%
plt.figure(figsize=(4, 4))
plt.hist(dataset['VB'], bins = 100, label = 'wear')
plt.legend()
plt.title('Wear distribution')
plt.show()

# %% [markdown]
# VB distribution/ data is imbalanced

# %%
grouped = dataset.groupby('machine')
plt.figure(figsize = (6,4))
for machine, group in grouped:
    plt.scatter(group['C'],
                group['VB'], label = f'machine {machine}',
                s = 10)
plt.xlabel('cumulated time')
plt.ylabel('wear')
plt.legend()
plt.title('machine')
plt.show()

# %% [markdown]
# strong correlation, machine 2 is biased.

# %%
dataset.columns
# Out:
# Index(['VB', 'C', 'tool', 'machine', 'torq_tot_mean', 'torq_tot_std',
#        'torq_tot_max', 'torq_tot_min', 'torq_tot_rms', 'torq_tot_skew',
#        'pcx_mean', 'pcx_std', 'pcx_max', 'pcx_min', 'pcx_rms', 'pcx_skew',
#        'pcy_mean', 'pcy_std', 'pcy_max', 'pcy_min', 'pcy_rms', 'pcy_skew',
#        'torque_x_mean', 'torque_x_std', 'torque_x_max', 'torque_x_min',
#        'torque_x_rms', 'torque_x_skew', 'torque_y_mean', 'torque_y_std',
#        'torque_y_max', 'torque_y_min', 'torque_y_rms', 'torque_y_skew',
#        'torque_z_mean', 'torque_z_std', 'torque_z_max', 'torque_z_min',
#        'torque_z_rms', 'torque_z_skew', 'torque_mean', 'torque_std',
#        'torque_max', 'torque_min', 'torque_rms', 'torque_skew', 'f_sens_mean',
#        'f_sens_std', 'f_sens_max', 'f_sens_min', 'f_sens_rms', 'f_sens_skew',
#        'fx_sens_mean', 'fx_sens_std', 'fx_sens_max', 'fx_sens_min',
#        'fx_sens_rms', 'fx_sens_skew', 'fy_sens_mean', 'fy_sens_std',
#        'fy_sens_max', 'fy_sens_min', 'fy_sens_rms', 'fy_sens_skew',
#        'fz_sens_mean', 'fz_sens_std', 'fz_sens_max', 'fz_sens_min',
#        'fz_sens_rms', 'fz_sens_skew', 'fx_mean', 'fx_std', 'fx_max', 'fx_min',
#        'fx_rms', 'fx_skew', 'fy_mean', 'fy_std', 'fy_max', 'fy_min', 'fy_rms',
#        'fy_skew', 'fz_mean', 'fz_std', 'fz_max', 'fz_min', 'fz_rms',
#        'fz_skew'],
#       dtype='object')

# %%
# mask = np.triu(np.ones_like(dataset.corr(method="spearman"), dtype=bool))

# plt.figure(figsize=(16, 14))
# sns.heatmap(
#     dataset.corr(method="spearman"),
#     mask=mask,
#     annot=False,
#     cmap='coolwarm',
#     center=0,
#     fmt='.2f',
# )

# plt.xticks(rotation=45, ha='right')  
# plt.yticks(rotation=0)           
# plt.tight_layout()               
# plt.show()

# %%
plt.figure(figsize=(5,5))
for c in dataset.columns.drop('VB'):
    corr = dataset['VB'].corr(dataset[c], method="spearman")
    if corr > 0.75:
        dataset[c] = dataset[c].apply(lambda x: (x - dataset[c].min()) / (dataset[c].max() ))
        plt.scatter(dataset[c], dataset['VB'], label = f'{c}: {corr:.2f}', s = 5)
plt.legend(bbox_to_anchor=(1.55, 1),loc= 'upper right')
plt.xlabel('C')
plt.ylabel('VB')
plt.title('correlation > 0.75')
plt.show()
# Out:
# /home/mina-joojoo/.local/lib/python3.10/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]

# %%
correlations = dataset.corr(method="spearman")['VB'].drop('VB')
high_corr_features = correlations[abs(correlations) > 0.7].index.tolist()
correlated_dataset = dataset[['VB', 'machine', 'tool'] + high_corr_features]
# Or PCA

# %%
X = correlated_dataset.drop('VB', axis=1)
y = correlated_dataset['VB']

# %%
from xgboost import XGBRegressor

model = XGBRegressor()
model.fit(X, y)

import pandas as pd
feat_imp = pd.Series(model.feature_importances_, index=X.columns)
feat_imp.sort_values().plot(kind="barh")
# Out:
# <Axes: >

# %%
sns.boxplot(x="machine", y="fy_sens_mean", data=correlated_dataset)
# Out:
# <Axes: xlabel='machine', ylabel='fy_sens_mean'>

# %%
# from scipy.fft import fft

# def extract_freq_features(x):
#     X = np.abs(fft(x))
    
#     return {
#         "energy": np.sum(X**2),
#         "peak_freq": np.argmax(X)
#     }

# %%
correlated_dataset
# Out:
#          VB  machine  tool         C  torque_x_mean  torque_x_max  \
# 0       3.0      1.0   1.0  0.000000       0.074497      0.061958
# 1       3.0      1.0   1.0  0.000772       0.077594      0.086741
# 2       4.0      1.0   1.0  0.001544       0.086920      0.094176
# 3       5.0      1.0   1.0  0.002316       0.050881      0.057002
# 4       6.0      1.0   1.0  0.003088       0.096201      0.090459
# ...     ...      ...   ...       ...            ...           ...
# 6413  158.0      3.0   9.0  0.660683            NaN           NaN
# 6414  159.0      3.0   9.0  0.661455            NaN           NaN
# 6415  159.0      3.0   9.0  0.662034            NaN           NaN
# 6416  159.0      3.0   9.0  0.662806            NaN           NaN
# 6417  160.0      3.0   9.0  0.663578            NaN           NaN
#
#       torque_x_min  torque_x_rms  torque_y_mean  torque_y_max  ...  \
# 0         0.042710      0.074372      -1.083756     -0.847554  ...
# 1         0.073638      0.078039      -1.084716     -0.852236  ...
# 2         0.075111      0.087224      -1.088038     -0.842871  ...
# 3         0.042710      0.051257      -1.088006     -0.849895  ...
# 4         0.103093      0.096356      -1.090966     -0.842871  ...
# ...            ...           ...            ...           ...  ...
# 6413           NaN           NaN            NaN           NaN  ...
# 6414           NaN           NaN            NaN           NaN  ...
# 6415           NaN           NaN            NaN           NaN  ...
# 6416           NaN           NaN            NaN           NaN  ...
# 6417           NaN           NaN            NaN           NaN  ...
#
#       fx_sens_mean  fx_sens_rms  fx_sens_skew  fy_sens_mean  fy_sens_max  \
# 0         0.027002     0.000000  1.145714e+05      0.008660     0.000000
# 1         0.030991     0.002938  1.050379e+05      0.009610     0.000710
# 2         0.034615     0.005545  8.546472e+04      0.012093     0.001667
# 3         0.037196     0.007500  8.238866e+04      0.014938     0.006936
# 4         0.038816     0.008839  7.927416e+04      0.017460     0.005220
# ...            ...          ...           ...           ...          ...
# 6413      0.592449     0.549588 -1.040985e+07      0.779792     0.645504
# 6414      0.592362     0.549807 -1.046673e+07      0.780101     0.655155
# 6415      0.594233     0.551617 -1.040608e+07      0.782677     0.643686
# 6416      0.596052     0.553545 -1.032460e+07      0.787336     0.667349
# 6417      0.596294     0.552795 -1.035864e+07      0.789610     0.719580
#
#       fy_sens_rms  fz_sens_mean     fx_mean    fx_rms    fy_max
# 0        0.010272     23.779776         NaN       NaN       NaN
# 1        0.009455     23.613913         NaN       NaN       NaN
# 2        0.008501     23.266512         NaN       NaN       NaN
# 3        0.007947     23.055359         NaN       NaN       NaN
# 4        0.008652     22.706730         NaN       NaN       NaN
# ...           ...           ...         ...       ...       ...
# 6413     0.656185    -44.843910 -369.502136  0.340477  0.448829
# 6414     0.655768    -43.836490 -412.305511  0.399840  0.447754
# 6415     0.660370    -43.907974 -477.872040  0.490784  0.450263
# 6416     0.660741    -44.326687 -485.143860  0.500893  0.451219
# 6417     0.662024    -44.268610 -433.501007  0.429239  0.448470
#
# [6418 rows x 28 columns]

# %%
cols_to_normalize = [col for col in correlated_dataset.columns if col not in ['machine', 'tool']]


dataset_normalized = correlated_dataset.copy()

for col in cols_to_normalize:
    min_val = correlated_dataset[col].min()  # NaN are ignored by default
    max_val = correlated_dataset[col].max()
    
    if max_val != min_val:  # Avoid division by zero
        dataset_normalized[col] = (correlated_dataset[col] - min_val) / (max_val - min_val)
    else:
        # If all values are the same, set to 0.5 or keep as is
        pass

# %%
dataset_normalized
# Out:
#             VB  machine  tool         C  torque_x_mean  torque_x_max  \
# 0     0.000000      1.0   1.0  0.000000       0.113359      0.097848
# 1     0.000000      1.0   1.0  0.000774       0.118073      0.136987
# 2     0.006369      1.0   1.0  0.001547       0.132263      0.148728
# 3     0.012739      1.0   1.0  0.002321       0.077424      0.090020
# 4     0.019108      1.0   1.0  0.003095       0.146385      0.142857
# ...        ...      ...   ...       ...            ...           ...
# 6413  0.987261      3.0   9.0  0.662089            NaN           NaN
# 6414  0.993631      3.0   9.0  0.662863            NaN           NaN
# 6415  0.993631      3.0   9.0  0.663443            NaN           NaN
# 6416  0.993631      3.0   9.0  0.664217            NaN           NaN
# 6417  1.000000      3.0   9.0  0.664990            NaN           NaN
#
#       torque_x_min  torque_x_rms  torque_y_mean  torque_y_max  ...  \
# 0         0.060797      0.113217       0.914575      0.726687  ...
# 1         0.104822      0.118800       0.912981      0.720257  ...
# 2         0.106918      0.132783       0.907463      0.733118  ...
# 3         0.060797      0.078028       0.907515      0.723472  ...
# 4         0.146751      0.146683       0.902601      0.733118  ...
# ...            ...           ...            ...           ...  ...
# 6413           NaN           NaN            NaN           NaN  ...
# 6414           NaN           NaN            NaN           NaN  ...
# 6415           NaN           NaN            NaN           NaN  ...
# 6416           NaN           NaN            NaN           NaN  ...
# 6417           NaN           NaN            NaN           NaN  ...
#
#       fx_sens_mean  fx_sens_rms  fx_sens_skew  fy_sens_mean  fy_sens_max  \
# 0         0.036712     0.000000      0.564510      0.007965     0.000000
# 1         0.042136     0.004217      0.564362      0.008839     0.000755
# 2         0.047063     0.007958      0.564056      0.011123     0.001772
# 3         0.050572     0.010765      0.564008      0.013739     0.007374
# 4         0.052774     0.012686      0.563959      0.016059     0.005550
# ...            ...          ...           ...           ...          ...
# 6413      0.805490     0.788777      0.400178      0.717210     0.686303
# 6414      0.805372     0.789091      0.399290      0.717495     0.696564
# 6415      0.807916     0.791689      0.400237      0.719864     0.684370
# 6416      0.810389     0.794456      0.401509      0.724149     0.709529
# 6417      0.810717     0.793379      0.400978      0.726241     0.765061
#
#       fy_sens_rms  fz_sens_mean   fx_mean    fx_rms    fy_max
# 0        0.011185      0.969655       NaN       NaN       NaN
# 1        0.010296      0.967939       NaN       NaN       NaN
# 2        0.009257      0.964344       NaN       NaN       NaN
# 3        0.008654      0.962159       NaN       NaN       NaN
# 4        0.009421      0.958551       NaN       NaN       NaN
# ...           ...           ...       ...       ...       ...
# 6413     0.714535      0.259497  0.564412  0.411767  0.408763
# 6414     0.714081      0.269923  0.488684  0.483559  0.407784
# 6415     0.719091      0.269183  0.372683  0.593544  0.410069
# 6416     0.719496      0.264850  0.359817  0.605770  0.410940
# 6417     0.720893      0.265451  0.451184  0.519113  0.408437
#
# [6418 rows x 28 columns]

# %%
# dataset_normalized.to_csv('correlated_dataset.csv', index=False)
