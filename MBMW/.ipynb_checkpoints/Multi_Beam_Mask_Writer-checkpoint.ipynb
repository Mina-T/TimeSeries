# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# Set random seed for reproducibility
np.random.seed(42)

# Parameters - Fixed to create larger dataset
start_date = datetime(2026, 5, 1)
end_date = datetime(2026, 8, 30)
num_weeks = 17  # May 1 to Aug 30 is about 17 weeks
features_per_day = 30  # 30 measurements per day (every 10 min from 9 AM to 2 PM)
total_features = len(pd.date_range(start=start_date, end=end_date, freq='D')) * features_per_day

# Generate timestamps (Monday to Friday, 9:00 AM to 5:00 PM)
date_range = pd.date_range(start=start_date, end=end_date, freq='D')
workdays = [d for d in date_range if d.weekday() < 5]  # Exclude weekends
timestamps = []
for day in workdays:
    for i in range(features_per_day):
        time = datetime(day.year, day.month, day.day, 9, 0, 0) + timedelta(minutes=10 * i)
        timestamps.append(time)
timestamps = pd.to_datetime(timestamps)

# Adjust total features to match actual timestamps
total_features = len(timestamps)

# Generate mask_ids (1 per day per writer)
mask_ids = []
current_mask = 0
for day in workdays:
    for writer in ['MBMW_03', 'MBMW_04', 'MBMW_05']:
        mask_id = f"M_{day.year}_{day.month:02d}_{day.day:02d}_{writer[-2:]}"
        for _ in range(features_per_day // 3):  # Distribute measurements across writers
            mask_ids.append(mask_id)
# Trim to exact length
mask_ids = mask_ids[:total_features]

# Generate writer_ids with realistic distribution
writer_ids = []
for i in range(total_features):
    if i % 3 == 0:
        writer_ids.append('MBMW_03')
    elif i % 3 == 1:
        writer_ids.append('MBMW_04')
    else:
        writer_ids.append('MBMW_05')

# Generate positions (0 to 5000 nm) with spatial patterns
x_positions = np.random.uniform(0, 5000, size=total_features).round(1)
y_positions = np.random.uniform(0, 5000, size=total_features).round(1)

# Add systematic spatial variation (edge effects)
center_distances = np.sqrt((x_positions - 2500)**2 + (y_positions - 2500)**2)
edge_effect = (center_distances / 2500) * 2  # 0 at center, 2 at edges

# Generate target_width (40, 50, 60, 70, 80 nm)
target_widths = np.random.choice([40.0, 50.0, 60.0, 70.0, 80.0], size=total_features)

# Generate exposure_dose (11.0 to 17.0 µC/cm², with drift and tool variation)
time_factor = np.linspace(0, 1, len(timestamps))  # 0 to 1 over time
tool_dose_bias = {'MBMW_03': 0, 'MBMW_04': 0.5, 'MBMW_05': -0.3}
exposure_doses = 14.0 + 2.0 * time_factor  # Base drift
for i, writer in enumerate(writer_ids):
    exposure_doses[i] += tool_dose_bias[writer]
exposure_doses += np.random.normal(0, 0.3, size=total_features)
exposure_doses = np.clip(exposure_doses, 11.0, 17.0).round(1)

# Generate temperature (21°C to 25°C, with daily cycle and drift)
hour_of_day = np.array([ts.hour + ts.minute/60 for ts in timestamps])
daily_temp_cycle = 1.5 * np.sin(2 * np.pi * (hour_of_day - 14) / 24)  # Peak at 2 PM
temperature = 22.0 + 2.0 * time_factor + daily_temp_cycle + np.random.normal(0, 0.3, size=total_features)
temperature = np.clip(temperature, 20.0, 26.0).round(1)

# Generate humidity (40% to 50%, with daily cycle)
humidity = 45.0 + 5.0 * np.sin(2 * np.pi * (hour_of_day - 6) / 24) + np.random.normal(0, 2, size=total_features)
humidity = np.clip(humidity, 35.0, 55.0).round(1)

# Generate vibration (0.01 to 0.10, with tool-specific patterns and random spikes)
vibration = np.random.uniform(0.01, 0.04, size=total_features)
# Add tool-specific vibration
for i, writer in enumerate(writer_ids):
    if writer == 'MBMW_03':
        vibration[i] += 0.02
    elif writer == 'MBMW_04':
        vibration[i] += 0.01
# Add random spikes
spike_indices = np.random.choice(total_features, size=int(total_features*0.01), replace=False)
vibration[spike_indices] = np.random.uniform(0.08, 0.15, size=len(spike_indices))
vibration = np.clip(vibration, 0.01, 0.15).round(3)

# Generate measured_width (target_width ± 5 nm, with systematic errors)
# Systematic errors from temperature, vibration, position, and tool
temp_error = (temperature - 22) * 0.3  # 0.3 nm per degree
vibration_error = vibration * 20  # up to 2 nm from vibration
position_error = edge_effect * 1.5  # edge placement error
tool_bias = {'MBMW_03': 0, 'MBMW_04': -0.8, 'MBMW_05': 0.5}

errors = np.random.normal(0, 1.5, size=total_features)  # Random noise
errors += temp_error + vibration_error + position_error

for i, writer in enumerate(writer_ids):
    errors[i] += tool_bias[writer]

# Add occasional large outliers (equipment issues)
outlier_indices = np.random.choice(total_features, size=int(total_features*0.02), replace=False)
errors[outlier_indices] += np.random.normal(8, 3, size=len(outlier_indices))

measured_widths = target_widths + errors
measured_widths = np.clip(measured_widths, 10.0, 150.0).round(1)

# Calculate CD error (Critical Dimension error)
cd_error = (measured_widths - target_widths).round(2)

# Generate defect flag (1 if CD error > 3 nm)
defect_flag = (np.abs(cd_error) > 3).astype(int)

# Generate feature_ids
feature_ids = [f"F_{i:06d}" for i in range(1, total_features + 1)]

# Add day and week columns as you wanted
df = pd.DataFrame({
    'feature_id': feature_ids,
    'timestamp': timestamps,
    'mask_id': mask_ids,
    'writer_id': writer_ids,
    'x_position': x_positions,
    'y_position': y_positions,
    'target_width': target_widths,
    'measured_width': measured_widths,
    'exposure_dose': exposure_doses,
    'temperature': temperature,
    'humidity': humidity,
    'vibration': vibration
})

# Add day and week columns
df['day'] = df['timestamp'].dt.day
df['week'] = df['timestamp'].dt.isocalendar().week
df['month'] = df['timestamp'].dt.month
df['hour'] = df['timestamp'].dt.hour
df['day_of_week'] = df['timestamp'].dt.dayofweek  # Monday=0, Sunday=6

# Save to CSV (fixed filename)
df.to_csv("metrology_data.csv", index=False)

# %%
data = pd.read_csv('metrology_data.csv')
data.head()
# Out:
#   feature_id            timestamp          mask_id writer_id  x_position  \
# 0   F_000001  2026-05-01 09:00:00  M_2026_05_01_03   MBMW_03      1872.7
# 1   F_000002  2026-05-01 09:10:00  M_2026_05_01_03   MBMW_04      4753.6
# 2   F_000003  2026-05-01 09:20:00  M_2026_05_01_03   MBMW_05      3660.0
# 3   F_000004  2026-05-01 09:30:00  M_2026_05_01_03   MBMW_03      2993.3
# 4   F_000005  2026-05-01 09:40:00  M_2026_05_01_03   MBMW_04       780.1
#
#    y_position  target_width  measured_width  exposure_dose  temperature  \
# 0       614.6          50.0            56.6           14.0         20.2
# 1      4443.3          80.0            82.6           13.9         20.0
# 2      2515.4          80.0            82.7           14.2         20.7
# 3      2246.7          80.0            80.5           13.9         20.5
# 4      2929.3          80.0            80.2           14.7         20.7
#
#    humidity  vibration  day  week  month  hour  day_of_week
# 0      47.5      0.054    1    18      5     9            4
# 1      42.0      0.047    1    18      5     9            4
# 2      47.7      0.024    1    18      5     9            4
# 3      51.1      0.057    1    18      5     9            4
# 4      51.9      0.035    1    18      5     9            4

# %%
data.shape
# Out:
# (2580, 17)

# %%
data.describe()
# Out:
#         x_position   y_position  target_width  measured_width  exposure_dose  \
# count  2580.000000  2580.000000   2580.000000     2580.000000    2580.000000
# mean   2497.585155  2467.855736     59.647287       62.783023      15.065155
# std    1456.406345  1436.340708     14.174712       14.323682       0.723997
# min       7.800000     0.100000     40.000000       37.600000      13.200000
# 25%    1215.025000  1233.225000     50.000000       51.700000      14.500000
# 50%    2530.050000  2452.200000     60.000000       62.600000      15.100000
# 75%    3758.150000  3705.325000     70.000000       74.200000      15.600000
# max    4998.600000  4997.800000     80.000000       96.300000      17.000000
#
#        temperature     humidity    vibration          day         week  \
# count  2580.000000  2580.000000  2580.000000  2580.000000  2580.000000
# mean     22.125078    49.587403     0.035571    15.651163    26.895349
# std       0.788446     2.039387     0.014332     8.688439     4.966024
# min      20.000000    42.000000     0.010000     1.000000    18.000000
# 25%      21.600000    48.200000     0.026000     8.000000    23.000000
# 50%      22.100000    49.600000     0.035000    15.500000    27.000000
# 75%      22.700000    50.900000     0.043250    23.000000    31.000000
# max      24.500000    55.000000     0.150000    31.000000    35.000000
#
#              month         hour  day_of_week
# count  2580.000000  2580.000000  2580.000000
# mean      6.488372    11.000000     2.023256
# std       1.097187     1.414488     1.422498
# min       5.000000     9.000000     0.000000
# 25%       6.000000    10.000000     1.000000
# 50%       6.500000    11.000000     2.000000
# 75%       7.000000    12.000000     3.000000
# max       8.000000    13.000000     4.000000

# %%
data.isnull().sum()
# Out:
# feature_id        0
# timestamp         0
# mask_id           0
# writer_id         0
# x_position        0
# y_position        0
# target_width      0
# measured_width    0
# exposure_dose     0
# temperature       0
# humidity          0
# vibration         0
# day               0
# week              0
# month             0
# hour              0
# day_of_week       0
# dtype: int64

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data['measured_width'], bins=40)
plt.title('Distribution of Measured Width')
plt.xlabel('Measured Width (nm)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=data[['measured_width', 'target_width', 'exposure_dose', 'temperature', 'humidity']])
plt.title('Boxplot of variables')
plt.show()

# %%
data['measure_error'] = abs(data['measured_width'] - data['target_width'])

# %%
plt.figure(figsize=(5, 5))
sns.histplot(data['measure_error'], bins=30)
plt.title('Distribution of Absolute Error (nm)')
plt.xlabel('Error (nm)')
plt.ylabel('Frequency')
plt.show()

# %%
data[data['measure_error'] > 2.5]
# Out:
#      feature_id            timestamp          mask_id writer_id  x_position  \
# 0      F_000001  2026-05-01 09:00:00  M_2026_05_01_03   MBMW_03      1872.7
# 1      F_000002  2026-05-01 09:10:00  M_2026_05_01_03   MBMW_04      4753.6
# 2      F_000003  2026-05-01 09:20:00  M_2026_05_01_03   MBMW_05      3660.0
# 7      F_000008  2026-05-01 10:10:00  M_2026_05_01_03   MBMW_04      4330.9
# 11     F_000012  2026-05-01 10:50:00  M_2026_05_01_04   MBMW_05      4849.5
# ...         ...                  ...              ...       ...         ...
# 2571   F_002572  2026-08-28 12:30:00  M_2026_08_28_05   MBMW_03      4530.6
# 2574   F_002575  2026-08-28 13:00:00  M_2026_08_28_05   MBMW_03      1130.1
# 2576   F_002577  2026-08-28 13:20:00  M_2026_08_28_05   MBMW_05      4894.9
# 2577   F_002578  2026-08-28 13:30:00  M_2026_08_28_05   MBMW_03      3017.5
# 2579   F_002580  2026-08-28 13:50:00  M_2026_08_28_05   MBMW_05      3239.1
#
#       y_position  target_width  measured_width  exposure_dose  temperature  \
# 0          614.6          50.0            56.6           14.0         20.2
# 1         4443.3          80.0            82.6           13.9         20.0
# 2         2515.4          80.0            82.7           14.2         20.7
# 7         3413.1          40.0            43.8           14.6         20.6
# 11        4019.8          80.0            82.6           13.8         20.9
# ...          ...           ...             ...            ...          ...
# 2571      1009.0          60.0            64.8           16.2         23.5
# 2574      3382.0          80.0            86.2           16.2         23.9
# 2576       920.2          50.0            55.9           15.3         23.1
# 2577      3782.3          60.0            64.1           15.7         23.6
# 2579      1128.9          50.0            54.7           16.0         23.9
#
#       humidity  vibration  day  week  month  hour  day_of_week  measure_error
# 0         47.5      0.054    1    18      5     9            4            6.6
# 1         42.0      0.047    1    18      5     9            4            2.6
# 2         47.7      0.024    1    18      5     9            4            2.7
# 7         46.2      0.027    1    18      5    10            4            3.8
# 11        49.7      0.019    1    18      5    10            4            2.6
# ...        ...        ...  ...   ...    ...   ...          ...            ...
# 2571      46.5      0.047   28    35      8    12            4            4.8
# 2574      49.9      0.036   28    35      8    13            4            6.2
# 2576      50.3      0.026   28    35      8    13            4            5.9
# 2577      50.4      0.035   28    35      8    13            4            4.1
# 2579      47.0      0.040   28    35      8    13            4            4.7
#
# [1582 rows x 18 columns]

# %%
for cor in ['pearson','spearman','kendall']:
    correlation = data[['measure_error', 'exposure_dose', 'temperature', 'humidity', 'vibration']].corr(method= cor)
    print(correlation['measure_error'].sort_values(ascending = False))
    plt.figure(figsize=(8, 5))
    sns.heatmap(correlation, cmap='coolwarm', center=0)
    plt.title(f'{cor} correlation Heatmap')
    plt.show()
# Out:
# measure_error    1.000000
# temperature      0.097460
# vibration        0.092438
# exposure_dose   -0.042010
# humidity        -0.044159
# Name: measure_error, dtype: float64
# measure_error    1.000000
# temperature      0.105813
# vibration        0.046668
# humidity        -0.048225
# exposure_dose   -0.055079
# Name: measure_error, dtype: float64
# measure_error    1.000000
# temperature      0.072796
# vibration        0.031921
# humidity        -0.032515
# exposure_dose   -0.037291
# Name: measure_error, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

env_factors = data[['temperature', 'humidity', 'vibration']]
y =  data['measure_error'].to_frame()

for f in env_factors:
    x = data[f].to_frame()
    model = LinearRegression().fit(x, y)
    plt.figure(figsize = (5,4))
    plt.scatter(data[f], data['measure_error'])
    plt.plot(x, model.predict(x), 'k')
    print(f'Slope: ',  model.coef_[0])
    plt.xlabel(f)
    plt.ylabel('measure_error')
    plt.show()
# Out:
# Slope:  [0.25259865]
# Slope:  [-0.04424818]
# Slope:  [13.17993037]

# %%
from scipy import stats

z_scores = stats.zscore(data['measure_error'])
outliers = data[z_scores> 3]
outliers
# Out:
#      feature_id            timestamp          mask_id writer_id  x_position  \
# 83     F_000084  2026-05-05 12:50:00  M_2026_05_05_05   MBMW_05       317.8
# 143    F_000144  2026-05-07 12:50:00  M_2026_05_07_05   MBMW_05      1504.4
# 238    F_000239  2026-05-12 13:40:00  M_2026_05_12_05   MBMW_04      3227.4
# 240    F_000241  2026-05-13 09:00:00  M_2026_05_13_03   MBMW_03      4702.3
# 252    F_000253  2026-05-13 11:00:00  M_2026_05_13_04   MBMW_03      4255.7
# 333    F_000334  2026-05-18 09:30:00  M_2026_05_18_03   MBMW_03       580.4
# 489    F_000490  2026-05-25 10:30:00  M_2026_05_25_03   MBMW_03      4451.3
# 561    F_000562  2026-05-27 12:30:00  M_2026_05_27_05   MBMW_03      1064.8
# 606    F_000607  2026-05-29 10:00:00  M_2026_05_29_03   MBMW_03      1031.7
# 655    F_000656  2026-06-01 13:10:00  M_2026_06_01_05   MBMW_04       637.9
# 786    F_000787  2026-06-08 10:00:00  M_2026_06_08_03   MBMW_03      2917.0
# 788    F_000789  2026-06-08 10:20:00  M_2026_06_08_03   MBMW_05      2310.0
# 967    F_000968  2026-06-16 10:10:00  M_2026_06_16_03   MBMW_04      1485.6
# 1049   F_001050  2026-06-18 13:50:00  M_2026_06_18_05   MBMW_05       106.3
# 1079   F_001080  2026-06-19 13:50:00  M_2026_06_19_05   MBMW_05      4749.8
# 1107   F_001108  2026-06-22 13:30:00  M_2026_06_22_05   MBMW_03      3791.2
# 1208   F_001209  2026-06-26 10:20:00  M_2026_06_26_03   MBMW_05      1368.1
# 1209   F_001210  2026-06-26 10:30:00  M_2026_06_26_03   MBMW_03      4985.6
# 1291   F_001292  2026-07-01 09:10:00  M_2026_07_01_03   MBMW_04       663.6
# 1521   F_001522  2026-07-10 12:30:00  M_2026_07_10_05   MBMW_03      4672.2
# 1623   F_001624  2026-07-16 09:30:00  M_2026_07_16_03   MBMW_03      4788.1
# 1800   F_001801  2026-07-24 09:00:00  M_2026_07_24_03   MBMW_03      4782.5
# 1834   F_001835  2026-07-27 09:40:00  M_2026_07_27_03   MBMW_04      4058.8
# 1837   F_001838  2026-07-27 10:10:00  M_2026_07_27_03   MBMW_04      1691.3
# 1913   F_001914  2026-07-29 12:50:00  M_2026_07_29_05   MBMW_05      1841.5
# 1985   F_001986  2026-08-03 09:50:00  M_2026_08_03_03   MBMW_05       403.0
# 1991   F_001992  2026-08-03 10:50:00  M_2026_08_03_04   MBMW_05       794.5
# 2043   F_002044  2026-08-05 09:30:00  M_2026_08_05_03   MBMW_03       573.8
# 2087   F_002088  2026-08-06 11:50:00  M_2026_08_06_04   MBMW_05      3283.9
# 2143   F_002144  2026-08-10 11:10:00  M_2026_08_10_04   MBMW_04      1571.8
# 2224   F_002225  2026-08-13 09:40:00  M_2026_08_13_03   MBMW_04        62.0
# 2304   F_002305  2026-08-17 13:00:00  M_2026_08_17_05   MBMW_03      4658.8
# 2338   F_002339  2026-08-18 13:40:00  M_2026_08_18_05   MBMW_04       605.1
# 2374   F_002375  2026-08-20 09:40:00  M_2026_08_20_03   MBMW_04      3364.8
# 2549   F_002550  2026-08-27 13:50:00  M_2026_08_27_05   MBMW_05       330.0
#
#       y_position  target_width  measured_width  exposure_dose  temperature  \
# 83        3389.1          50.0            59.5           13.4         21.7
# 143       2290.0          80.0            93.4           13.9         21.9
# 238         45.2          60.0            74.3           15.0         22.0
# 240       4631.0          70.0            84.0           14.4         20.6
# 252        592.5          80.0            89.6           14.3         20.9
# 333       4834.2          70.0            82.5           13.9         21.3
# 489       3380.1          60.0            73.7           14.2         21.0
# 561       4603.8          70.0            84.9           14.9         21.9
# 606       1784.4          80.0            92.1           14.4         21.1
# 655       1171.0          60.0            78.5           15.1         22.4
# 786       1622.6          80.0            93.7           14.5         21.2
# 788        954.6          70.0            81.7           14.7         21.4
# 967       2422.7          50.0            61.7           15.3         21.5
# 1049      3136.6          60.0            74.6           14.6         23.0
# 1079      4553.0          50.0            62.6           14.3         22.9
# 1107      1936.6          70.0            83.7           15.0         22.8
# 1208       593.5          50.0            59.4           14.8         22.3
# 1209      4902.8          60.0            75.7           15.1         21.4
# 1291       908.9          60.0            71.4           15.4         21.6
# 1521      2132.0          40.0            56.1           15.3         22.6
# 1623      4817.4          50.0            61.0           15.0         22.2
# 1800       310.2          50.0            60.5           15.2         21.9
# 1834      2053.9          40.0            54.3           15.7         22.2
# 1837       120.0          40.0            54.9           15.8         22.6
# 1913      3981.2          40.0            50.4           15.2         23.1
# 1985      4486.9          80.0            90.9           15.3         22.7
# 1991      3374.5          80.0            96.3           15.3         22.9
# 2043      3451.6          80.0            92.7           15.4         22.0
# 2087      4194.3          60.0            70.8           15.4         22.7
# 2143      2093.5          50.0            63.4           16.3         22.7
# 2224      4106.3          70.0            81.7           16.5         22.1
# 2304       549.3          50.0            64.8           15.9         23.8
# 2338      3799.1          50.0            63.3           16.0         24.1
# 2374      2251.8          70.0            81.3           16.4         22.9
# 2549      4260.2          40.0            53.3           15.8         24.4
#
#       humidity  vibration  day  week  month  hour  day_of_week  measure_error
# 83        49.4      0.010    5    19      5    12            1            9.5
# 143       47.6      0.117    7    19      5    12            3           13.4
# 238       50.5      0.025   12    20      5    13            1           14.3
# 240       45.0      0.043   13    20      5     9            2           14.0
# 252       53.5      0.042   13    20      5    11            2            9.6
# 333       47.4      0.045   18    21      5     9            0           12.5
# 489       48.8      0.048   25    22      5    10            0           13.7
# 561       50.6      0.056   27    22      5    12            2           14.9
# 606       51.3      0.052   29    22      5    10            4           12.1
# 655       51.0      0.033    1    23      6    13            0           18.5
# 786       46.4      0.047    8    24      6    10            0           13.7
# 788       47.4      0.016    8    24      6    10            0           11.7
# 967       51.8      0.043   16    25      6    10            1           11.7
# 1049      51.6      0.019   18    25      6    13            3           14.6
# 1079      47.8      0.028   19    25      6    13            4           12.6
# 1107      53.9      0.047   22    26      6    13            0           13.7
# 1208      54.8      0.034   26    26      6    10            4            9.4
# 1209      52.1      0.048   26    26      6    10            4           15.7
# 1291      50.4      0.040    1    27      7     9            2           11.4
# 1521      45.5      0.036   10    28      7    12            4           16.1
# 1623      46.3      0.051   16    29      7     9            3           11.0
# 1800      44.9      0.043   24    30      7     9            4           10.5
# 1834      46.2      0.046   27    31      7     9            0           14.3
# 1837      51.6      0.024   27    31      7    10            0           14.9
# 1913      48.7      0.020   29    31      7    12            2           10.4
# 1985      50.5      0.038    3    32      8     9            0           10.9
# 1991      48.2      0.015    3    32      8    10            0           16.3
# 2043      49.2      0.039    5    32      8     9            2           12.7
# 2087      48.9      0.020    6    32      8    11            3           10.8
# 2143      49.4      0.021   10    33      8    11            0           13.4
# 2224      47.1      0.049   13    33      8     9            3           11.7
# 2304      48.9      0.037   17    34      8    13            0           14.8
# 2338      50.4      0.039   18    34      8    13            1           13.3
# 2374      49.9      0.042   20    34      8     9            3           11.3
# 2549      49.8      0.029   27    35      8    13            3           13.3

# %%
data['timestamp'] = pd.to_datetime(data['timestamp'])

# %%
data['Day']= data['timestamp'].dt.date
data['Week'] = data['timestamp'].dt.isocalendar().week
daily_error = data.groupby(data['Day'])['measure_error'].mean().reset_index()

# %%
daily_error
# Out:
#            Day  measure_error
# 0   2026-05-01       2.560000
# 1   2026-05-04       3.500000
# 2   2026-05-05       2.910000
# 3   2026-05-06       2.336667
# 4   2026-05-07       3.323333
# ..         ...            ...
# 81  2026-08-24       3.306667
# 82  2026-08-25       3.013333
# 83  2026-08-26       3.540000
# 84  2026-08-27       3.450000
# 85  2026-08-28       3.280000
#
# [86 rows x 2 columns]

# %%
daily_error['rolling_avg'] = daily_error['measure_error'].rolling(window=5).mean()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=daily_error, x='Day', y='measure_error', label='Error')
sns.lineplot(data=daily_error, x='Day', y='rolling_avg', label='7-Day Rolling Avg')
plt.title('7-Day Rolling Average of Error')
plt.xlabel('Date')
plt.ylabel('Mean Error (nm)')
plt.legend()
plt.show()
